# %%
using Distributions
using StatsPlots


plot(Beta(5,2), fillrange=0, fillalpha=0.2)

# %%
typemax(Float32)
10^19
# Out:
# -8446744073709551616

# %%
x = 2
x÷(x-1)

hypot(x,2x)
# Out:
# 4.47213595499958
